# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Кристина :) Спасибо за доработки 🤝
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + создать выборку в подразделе портретов из ТОП-5 и категории «другие»
#  + в разделе проверки гипотез можно более подробно расшифровать значение p_value, поправить уровень значимости и вывод
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# подсказки добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Кристина :) Спасибо, что прислала задание 🤝 Твой старый знакомый, Ринат Хисамов будет проверять  проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование факторов популярности и спроса на компьютерные и кросс-платформенные игры

# %% [markdown]
# **Цель исследования:** выявить закономерности, определяющие успешность игры.
# <br/>Достичь поставленной цели можно **двумя способами: исследовательским анализом и проверкой гипотез.**
#
# <br/>**План исследовательского анализа:**
# - определить сколько игр выпускалось в разные годы и период с наиболее важными данными;
# - определить как менялись продажи по платформам;
# - выбрать платформы с наибольшими суммарными продажами и построить распределение по годам для определения характерного срока, в который появляются новые и исчезают старые платформы;
# - определить на основе данных за определенный ранее актуальный период, какие платформы лидируют по продажам, растут или падают;
# - выбрать несколько потенциально прибыльных платформ и построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам;
# - определить как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков и сравнить полученные выводы с продажами игр на других платформах;
# - рассмотреть общее распределение игр по жанрам и сформулировать выводы о самых прибыльных.
#
# <br/>**Для выполнения проекта также небходимо проверить следующие гипотезы:**
# - средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ясная и четкая вступительная часть проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %%
#загружаем библиотеки
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from math import factorial

# %%
import numpy as np

# %%
import seaborn as sns

# %%
from scipy import stats as st

# %%
games = pd.read_csv('games.csv')
games.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# **Описание данных:**
#
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# **Вывод:**
# <br/>При знакомстве с данными видим следующее:
#
# - наименования столбцов не соответствуют змеиному регистру;
# - данные содержат пропуски;
# - неправильный тип данных у столбцов Year_of_Release (д.б. int) и User_Score (д.б. float).

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и первичное знакомство с данными проведены корректно

# %% [markdown]
# ### Подготовьте данные

# %% [markdown]
# #### Замените названия столбцов (приведите к нижнему регистру)

# %%
games.columns = games.columns.str.lower()
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# #### Обработайте пропуски при необходимости:
# - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# - Опишите причины, которые могли привести к пропускам;
# - Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать

# %%
#процент пропусков в каждом столбце
games.isna().mean().sort_values(ascending=False)
#отсортируем для понимания в каких столбцах наибольшее кол-во пропусков
# Out:
# critic_score       0.513192
# rating             0.404786
# user_score         0.400897
# year_of_release    0.016093
# name               0.000120
# genre              0.000120
# platform           0.000000
# na_sales           0.000000
# eu_sales           0.000000
# jp_sales           0.000000
# other_sales        0.000000
# dtype: float64

# %% [markdown]
# Больше всего пропусков в столбцах: critic_score (оценка критиков), rating (рейтинг) и user_score (оценка пользователей).
# <br/>Заполнить эти пропуски медианным или средним значениями будет некорректно, т.к. это сильно исказит данные для дальнейшего исследования.
# <br/>Удалить эти пропуски тоже нельзя, т.к. их от 40% в каждом, из перечисленных, столбце, а критичный уровень потерь записей на этапе предобработки составляет 10% (оптимальный 5%), поэтому пропуски в столбцах с оценками и рейтингом оставляем нетронутыми.

# %% [markdown]
# Далее поработаем с пропусками в столбцах: year_of_release (год выпуска), name (название игры), genre (жанр).

# %% [markdown]
# Посмотрим пропуски в year_of_release:

# %%
games[games['year_of_release'].isna()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# 269 пропусков в столбце с годом релиза. Их также нельзя заполнить медианой или средним и, т.к. их менее 2% от всех данных, от них можно просто избавиться.

# %%
games = games.dropna(subset=['year_of_release'])
games['year_of_release'].isna().sum()
# Out:
# 0

# %% [markdown]
# Посмотрим пропуски в name:

# %%
games[games['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Всего две строки и NaN в большинстве столбцов, удаляем.

# %%
games = games.dropna(subset=['name'])
games['name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Посмотрим пропуски в genre:

# %%
games[games['genre'].isna()] #пропусков уже нет, т.к. они были в тех же строках, что и в name
games['name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Проверим данные на наличие дубликатов:

# %%
#проверим на наличие явных дубликатов
games.duplicated().sum()
# Out:
# 0

# %%
games.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         6605
# rating             6676
# dtype: int64

# %% [markdown]
# Также проверим наличие дубликатов в столбцах name, platform, years_of_release:

# %%
len(games)
# Out:
# 16444

# %%
game_description = games.loc[:, 'name':'year_of_release']
game_description[game_description.duplicated()]
game_description.duplicated().sum() #один дубликат
# Out:
# 1

# %%
#удаляем его и методом reset_index(drop=True) создаем новые индексы и удаляем старые
games = games.drop_duplicates(subset=['name', 'platform', 'year_of_release'], keep='first').reset_index(drop=True)

len(games)
# Out:
# 16443

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Решение верное, перед удалением стоит посмотреть на записи — может  это не дубликаты

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделала, добавила - game_description[game_description.duplicated()]

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# **Расшифровка 'tbd':**
# <br/>TBD - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено). Используется, если какая-то информация еще не определена или решение по вопросу не принято. Акроним служит для отметки неясностей или пропусков, которые надо заполнить, в информации требований.

# %% [markdown]
# Исходя из расшифровки, можно предлоположить, что 'tbd' в столбце с оценкой пользователей (user_score) означает, что оценки отсутствуют. Поэтому меняем 'tbd' на NaN для дальнейшей работы с таблицей.

# %%
games['user_score'] = games['user_score'].replace('tbd', np.nan)
#games.isna().sum()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %% [markdown]
# В столбце rating содержиться несколько категорий, общее число значений по которым не достигает и 10 шт., посмотрим что это за категории:

# %% [markdown]
# Обратимся к объяснению рейтинга ESRB:
#
# https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board
#
# - AO - Adults only 18+ - можно объединить с рейтингом Mature (17+);
# - RP - Rating Pending - рейтинг ожидается;
# - EC - Early childhood - можно объединить с рейтингом Everyone (6+)
# - К-А - Kids to Adults - старое название рейтинга Everyone (6+), объединяем с ним.

# %% [markdown]
# А также заполняем нулевые значения рейтингом unknown:

# %%
games['rating'] = games['rating'].fillna('unknown')
games['rating'].value_counts()
# Out:
# rating
# unknown    6676
# E          3920
# T          2905
# M          1536
# E10+       1393
# EC            8
# K-A           3
# AO            1
# RP            1
# Name: count, dtype: int64

# %%
games.loc[games['rating'] == 'AO', 'rating'] = 'M'
games.loc[games['rating'].isin(['EC', 'K-A']), 'rating'] = 'E'

# %%
games['rating'].value_counts()
# Out:
# rating
# unknown    6676
# E          3931
# T          2905
# M          1537
# E10+       1393
# RP            1
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> По второй части совета
#
#         unknown    6676
#         E          3931
#         T          2905
#         M          1537
#         E10+       1393
#
#
#         RP            1
#
# стоит ответить на вопрос — нужна ли нам эта малочисленная категория? Может стоит объединить?

# %% [markdown]
# #### Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему

# %%
games['year_of_release'] = games['year_of_release'].astype('int')
games['user_score'] = games['user_score'].astype('float')
#games.info()

# %% [markdown]
# #### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец

# %%
games['sum_sales'] = games[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)
#games.head()

# %% [markdown]
# **Вывод:**
# - Избавились от пропусков там, где это было возможно;
# - Проверили данные на наличие дубликатов;
# - Привели столбцы user_score и year_of_release к правильному типу данных;
# - Добавили столбец с суммарными продажами во всех регионах.

# %%
# check
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16443 entries, 0 to 16442
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int32
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       7462 non-null   float64
#  10  rating           16443 non-null  object
#  11  sum_sales        16443 non-null  float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг ESRB — категориальные данные, стоит внимательно взглянуть на содержимое и предложить чем заполнить пропуски, возможно это поможет найти необычные различия в поведении клиентов, допом можно подумать над сокращением количества категорий
#
# Т.к. записи с пропусками не учитываются при группировке данных, мы не сможем выявить реальный портрет игрока

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Дополнила в конце пункта 2.1.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# ####  Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
games.plot(y='year_of_release', x='sum_sales', 
           kind='hist', 
           bins=70, 
           grid=True, 
           figsize=(12, 4), 
           range=(1980, 2017), 
           color=('#edff67'),
           legend=False)
plt.title('Выпуск игр с 1980 по 2016 годы')
plt.xlabel('Годы')
plt.ylabel('Количество игр');

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все элементы добавлены, молодец

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит развернуть и сократить кол-во надписей на оси Х
#
#         1980 - 1985 - 1990 ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сократила.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, молодец

# %% [markdown]
# Выпуск игр начался с 1980 год, но набирать популярность этот вид досуга стал только к середине 90-х годов. Скорее всего это связано с тем, что персональные компьютеры стали доступны широкому кругу пользователей.
# <br/>После 2000-х наблюдается резкий рост, это также связано со стремительным развинием технологической отрасли.
# <br/>Пик выпуска игр приходится на 2008-2009 годы, спад после 2010 года можно объяснить разгаром мирового экономического кризиса (2008-2013).
# <br/>После окончания острой фазы кризиса вновь появились ресурсы на разработку, т.к. на нее обычно уходит несколько лет, очередной рост виден к 2015 году.

# %% [markdown]
# ####  Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
platform_sales = games.pivot_table(index='platform',
                                   values='sum_sales',
                                   aggfunc='sum')\
                                   .sort_values(ascending=False, by = 'sum_sales')
platform_sales.plot(kind='bar',
                    figsize=(12, 4),
                    legend=False,
                    grid = True,
                    color=('#6fff67'))
plt.title('Развитие продаж')
plt.xlabel('Название платформы')
plt.ylabel('Количество игр');

# %% [markdown]
# На графике явно видно, что лидерами продаж являются все версии PS, консоли Nintendo - DS и Wii, и X360 от Microsoft.

# %% [markdown]
# Далее выберем лидирующие платформы (ТОП-6) и построим распределение по годам, чтобы определить, за какой характерный срок появляются новые и исчезают старые платформы:

# %%
for top in platform_sales.index[:6]:
    games.query('platform == @top')\
    .pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum')\
    .plot(kind='bar',
          figsize=(8, 4),
          legend=False,
          grid = True,
          color=('#6fff67'))
    plt.xlabel('Год')
    plt.ylabel('Количество')
    plt.title(top)
    plt.show()

# %% [markdown]
# По графикам видно, что средний срок жизни платформы на рынке около 10 лет.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение жизненного цикла продаж у платформ, молодец

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16443 entries, 0 to 16442
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int32
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       7462 non-null   float64
#  10  rating           16443 non-null  object
#  11  sum_sales        16443 non-null  float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 1.4+ MB

# %%
games.query('platform == "DS" and year_of_release == 1985')
# Out:
#                                       name platform  year_of_release   genre  \
# 15704  Strongest Tokyo University Shogi DS       DS             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15704       0.0       0.0      0.02          0.0           NaN         NaN
#
#         rating  sum_sales
# 15704  unknown       0.02

# %%
games = games.drop(labels = [15704],axis = 0) #удаляю выброс
games.query('platform == "DS"').pivot_table(index='year_of_release', 
                                            values='sum_sales', 
                                            aggfunc='sum').plot(kind='bar',
                                                                figsize=(8, 4),
                                                                legend=False,
                                                                grid = True,
                                                                color=('#6fff67'))
plt.xlabel('Год')
plt.ylabel('Количество')
plt.title(top)
plt.show()

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Да, действительно выброс, т.к. релиз DS состоялся только в 2004 году. Избавилась от него.
#
# <br /> У меня максимально тупой вопрос :)
# <br /> Я когда нашла выброс методом games.query('platform == "DS" and year_of_release == 1985'), хотела перезаписать таблицу
# games = games.query('platform == "DS" and year_of_release **!=** 1985'), у меня почему-то после этого при вызове info() осталось чуть больше 2-х тысяч строк и это все были строки с платформой DS. Я не понимаю почему, что не так в логической фильтрации. Просто если убрать platform == "DS", то получится, что снесутся все платформы с релизом в 1985 году, ну и оператор and еще стоит, который указывает, что оба условия должны соблюдаться. В общем я что-то затупила и поэтому удалила строку вручную.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Тупых вопросов на этом курсе не бывает 🤝
#
# Твое условие работает так, как ты и написала — оставляет только игры выпущенные на платформе DS, кроме 1985 года, все остальные игры удаляет
#
#         games.query('platform == "DS" and year_of_release != 1985'),
#
# Для корректного выполнения стоит поменять логику фильтрации — сказать программе: оставить все записи кроме платформы DS из 1985 года, т.е.
#
#        .query('~(platform == "DS" and year_of_release == 1985)')
#
# `~` — это знак отрицания

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит полностью оформить все графики на проекте
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавила подписи осей и заголовки.

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# #### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.

# %% [markdown]
# Для дальнейшего анализа оставляем в таблице данные только за 2014-2016 годы.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Взяла данные за 2014-2016 годы.

# %%
actual_games = games.query('year_of_release >= 2014')
actual_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1689 entries, 31 to 16442
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1689 non-null   object
#  1   platform         1689 non-null   object
#  2   year_of_release  1689 non-null   int32
#  3   genre            1689 non-null   object
#  4   na_sales         1689 non-null   float64
#  5   eu_sales         1689 non-null   float64
#  6   jp_sales         1689 non-null   float64
#  7   other_sales      1689 non-null   float64
#  8   critic_score     718 non-null    float64
#  9   user_score       888 non-null    float64
#  10  rating           1689 non-null   object
#  11  sum_sales        1689 non-null   float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 164.9+ KB

# %% [markdown]
# #### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ. Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
actual_games.groupby('platform')['sum_sales'].agg('sum').sort_values(ascending=False)
# Out:
# platform
# PS4     288.15
# XOne    140.36
# 3DS      86.68
# PS3      68.18
# X360     48.22
# WiiU     42.98
# PC       27.05
# PSV      22.40
# Wii       5.07
# PSP       0.36
# Name: sum_sales, dtype: float64

# %% [markdown]
# Потенциально прибыльными можно назвать следующие платформы: PS4, XOne, 3DS, PS3, X360, WiiU, PC и PSV.
#
# Лидер продаж - PS4 - 288.15 млн. проданных копий.
# <br/>В два раза меньше продаж у модели - XOne - 140.36 млн. проданных копий.
# <br/>Далее - 3DS - 86.68 млн. проданных копий, PS3 - 68.18 млн. проданных копий, X360 - 48.22 млн. проданных копий, WiiU - 42.98 млн. проданных копий, PC - 27.05 млн. проданных копий и PSV - 22.40 млн. проданных копий.
#
# PS4 на текущий момент является наиболее перспективной, до выхода новой версии. Несмотря на второе место, на PS3 не стоит делать ставку, т.к. ее релиз состоялся в 2006 году, то, помня о средней продолжительности жизненого цикла платформы в, примерно, 10 лет, можно предположить, что спрос будет падать.
# <br/>Релиз X360 состоялся в 2005 году, ситуация аналогичная с PS3, спрос так же будет падать.
# XOne, выпущенная в 2013 году, тоже может быть потенциально прибыльной.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить перечень перспективных платформ
#
#
# даже  на падающих продажах можно заработать, когда объем составляет около 15-20 млн. копий, как например с 3DS
#
# 30-тилетняя история персональных компьютеров говорит, что игры для PC можно включить в рекомендацию

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправила вывод.

# %% [markdown]
# Построим диаграммы размаха:

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data=actual_games, x='platform', y='sum_sales')
ax.set_ylim(0, 2)
ax.set_ylabel('Продажи игр, млн. шт.')
ax.set_xlabel('Платформы')
ax.set_title('Распределение продаж платформ за 2014-2016 годы')
plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data=actual_games, x='platform', y='sum_sales')
ax.set_ylabel('Продажи игр, млн. шт.')
ax.set_xlabel('Платформы')
ax.set_title('Распределение продаж платформ за 2014-2016 годы')
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, ты используешь диаграмму размаха для определения успешности платформы, молодец
#
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом, посмотреть на максимальные продажи

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не поняла про "график со 100% масштабом" :(

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит добавить диаграмму размаха в 100% масштабе
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавила.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Не стоит ограничивать перечень платформ из актуального периода для оценки прибыльности платформ__
#
# диаграмму размаха перерисовать на актуальной выборке с полным перечнем платформ

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправила график.

# %% [markdown]
# Наиболее потенциально коммерчески успешные платформы: PS4, XOne, WiiU, X360 и Wii.
# У остальных медиана значительно ниже.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ты правильно заметила в предыдущем абзаце —
#
# "PS3" уже исполнилось 11 лет и она с малой вероятностью станет перспективной в 2017 году

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправила вывод согласно новому графику.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# "Х360" также исполнилось 11 лет

# %% [markdown]
# #### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы. Соотнесите выводы с продажами игр на других платформах.

# %%
def ratio_user_score(game):
  game.plot.scatter(x = 'user_score', y = 'sum_sales', alpha=0.3)
  plt.title('Зависимость продаж от отзывов пользователей')
  plt.xlabel('Рейтинг пользователей')
  plt.ylabel('Продажи')
  corr = round(game['user_score'].corr(game['sum_sales']), 2)
  result = 'Коэффициент корреляции: ' + str(corr)
  return result

def ratio_critic_score(game):
  game.plot.scatter(x = 'critic_score', y = 'sum_sales', alpha=0.3)
  plt.title('Зависимость продаж от отзывов критиков')
  plt.xlabel('Рейтинг критиков')
  plt.ylabel('Продажи')
  corr = round(game['critic_score'].corr(game['sum_sales']), 2)
  result = 'Коэффициент корреляции: ' + str(corr)
  return result

# %%
pl_ps4 = actual_games.query('platform == "PS4"')
ratio_user_score(pl_ps4)
# Out:
# 'Коэффициент корреляции: -0.04'

# %%
ratio_critic_score(pl_ps4)
# Out:
# 'Коэффициент корреляции: 0.4'

# %%
pl_ps3 = actual_games.query('platform == "PS3"')
ratio_user_score(pl_ps3)
# Out:
# 'Коэффициент корреляции: -0.17'

# %%
ratio_critic_score(pl_ps3)
# Out:
# 'Коэффициент корреляции: 0.45'

# %%
pl_xone = actual_games.query('platform == "XOne"')
ratio_user_score(pl_xone)
# Out:
# 'Коэффициент корреляции: -0.07'

# %%
ratio_critic_score(pl_xone)
# Out:
# 'Коэффициент корреляции: 0.43'

# %%
pl_3ds = actual_games.query('platform == "3DS"')
ratio_user_score(pl_3ds)
# Out:
# 'Коэффициент корреляции: 0.22'

# %%
ratio_critic_score(pl_3ds)
# Out:
# 'Коэффициент корреляции: 0.31'

# %%
pl_x360 = actual_games.query('platform == "X360"')
ratio_user_score(pl_x360)
# Out:
# 'Коэффициент корреляции: -0.14'

# %%
ratio_critic_score(pl_x360)
# Out:
# 'Коэффициент корреляции: 0.53'

# %% [markdown]
# По всем рассмотренным платформам (кроме 3DS) в отличие от оценок пользователей, оценки критиков имеют определенное значение повышают шансы на продажу.
# <br/>На платформе 3DS оценки пользователей влияют на продажи значительно больше.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Сравнение показателей на нескольких платформах, позволяет набрать вес твоему исследованию, молодец
#
#         классная автоматизация кода, молодец

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# #### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
genres = actual_games.groupby('genre')['genre'].count().sort_values(ascending=True)
genres.plot(kind='barh', figsize=(8, 4), grid=True, legend=False, color=('#6fff67'))
plt.xlabel('Количество')
plt.ylabel('Жанр')
plt.title('Наиболее популярные жанры')
plt.show()

# %%
#genres = games.groupby('genre')['genre'].count()
#plt.figure(figsize=(20,7))
#plt.pie(x=genres, labels=popular_genres, autopct="%.2f")
#plt.show()

# %% [markdown]
# Наиболее популярные жанры - action, role-playing  и adventure.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Круговая диаграмма малоинформативна для кол-ва категорий более 5-ти, невозможно за 5 сек. сравнить и решить какой вид жанра является отстающим, а самое главное определить — насколько сильно они различаются друг от друга

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Переделала график с 'pie' на 'barh', но не нашла как указать % на таком графике.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Чтобы указать проценты, придется переделать сводную таблицу, по который строится график
#
#         actual_games.groupby('genre')['genre'].count().sort_values(ascending=True)

# %%
#popular_genre = games.groupby('genre')[['sum_sales']].mean().sort_values('sum_sales', ascending=False).style.bar()

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data=actual_games, x='genre', y='sum_sales')
ax.set_ylim(0, 4)
ax.set_ylabel('Количество')
ax.set_xlabel('Жанры')
ax.set_title('Распределение продаж платформ по жанрам')
plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data=actual_games, x='genre', y='sum_sales')
ax.set_ylabel('Количество')
ax.set_xlabel('Жанры')
ax.set_title('Распределение продаж платформ по жанрам')
plt.show()

# %% [markdown]
# Игры в жанрах action, sports и adventure, приносят наибольшее количество продаж.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить вывод
#
#         Игры в жанрах action, sports и adventure, приносят наибольшее количество продаж.
#
# о продажах судят не по кол-ву выпущенных игр, а по прибыли. Т.к. у нас нет прибыли, мы ориентируемся на кол-во продаж
#
# Этот график про количество игр
#
#         actual_games.groupby('genre')['genre'].count().sort_values(ascending=True)
#
# Этот график про сумму продаж
#
#         sns.boxplot(data=actual_games, x='genre', y='sum_sales')

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я очень сильно надеюсь, что это то, что ты имел ввиду :)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Ящики, усы и скрипки](https://habr.com/ru/articles/533726/)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)
#
# https://stackoverflow.com/questions/22028064/matplotlib-boxplot-without-outliers

# %% [markdown]
# **Вывод:**
#
# - Выпуск игр начался с 1980 год, но набирать популярность этот вид досуга стал только к середине 90-х годов. Скорее всего это связано с тем, что персональные компьютеры стали доступны широкому кругу пользователей.
# <br/>После 2000-х наблюдается резкий рост, это также связано со стремительным развинием технологической отрасли.
# <br/>Пик выпуска игр приходится на 2008-2009 годы, спад после 2010 года можно объяснить разгаром мирового экономического кризиса (2008-2013).
# <br/>После окончания острой фазы кризиса вновь появились ресурсы на разработку, т.к. на нее обычно уходит несколько лет, очередной рост виден к 2015 году.
# - Лидерами продаж: все версии PS, консоли Nintendo - DS и Wii, и X360 от Microsoft.
# - Средний срок жизни платформы - 10 лет.
# - Актуальный периодом для дальнейшего исследования - с 2014 по 2016 годы, т.к. 2-3 года - актуальный срок для прогнозирования.
# - Лидеры за актуальный период - это платформы PS4, XOne, 3DS, PS3, X360, WiiU, PC и PSV.
# - Наиболее потенциально коммерчески успешные платформы: PS4, XOne, WiiU, X360 и Wii. У остальных медиана значительно ниже.
# - Оценки критиков имеют определенное значение повышают шансы на продажу по всем рассмотренным платформам, в отличие от оценок пользователей. Но на платформе 3DS оценки пользователей влияют на продажи значительно больше.
# - Наиболее популярные жанры - action, role-playing и adventure.
# <br/>Игры в жанрах action, sports и adventure, приносят наибольшее количество продаж.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить нюансы в промежуточном выводе

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправила.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить нюансы в промежуточном выводе

# %% [markdown]
# ### Составьте портрет пользователя каждого региона

# %% [markdown]
# #### Определите для пользователя каждого региона (NA, EU, JP):
#
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
# Выбор топ-5 платформ
top_platforms = platform_sales[:5]
# Суммирование продаж остальных платформ
other_sales = platform_sales[5:].sum()
# Добавление категории "другие" в список топ-5
top_platforms.loc[len(top_platforms.index )] = other_sales
display(type(top_platforms))
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_18828\1864322159.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_platforms.loc[len(top_platforms.index )] = other_sales
# pandas.core.frame.DataFrame

# %%
# check
top_platforms
# Out:
#           sum_sales
# platform
# PS2         1233.56
# X360         961.24
# PS3          931.33
# Wii          891.18
# DS           802.78
# 5           3994.27

# %%
def popular_platforms_multiple():
    regions = [('na_sales', 'Северной Америке'), ('eu_sales', 'Европе'), ('jp_sales', 'Японии')]
    fig, axes = plt.subplots(1, 3, figsize=(18, 6)) 
    fig.suptitle('Обзор рынка платформ') 
    for i, (region, name) in enumerate(regions):
        sales_t = actual_games.pivot_table(index='platform', values=region, aggfunc='sum')\
                                     .sort_values(ascending=False, by=region)
        platform_sales = sales_t[:5]
        platform_sales.loc[len(platform_sales.index)] = sales_t[5:].sum()
        platform_sales.rename(index={5:"other"}, inplace= True)
        platform_sales.plot(kind='pie', y=region, autopct='%1.1f%%', 
                            colors=['#7169c9', '#a3a0fb', '#cfc3ff', '#e8e5fd', '#f0f0f0'],
                            ax=axes[i], legend=False, title='Популярность платформ в ' + name)
        axes[i].set_ylabel('')
    plt.show()

# %%
popular_platforms_multiple()
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_18828\584226.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   platform_sales.loc[len(platform_sales.index)] = sales_t[5:].sum()
# C:\Users\artem\AppData\Local\Temp\ipykernel_18828\584226.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   platform_sales.rename(index={5:"other"}, inplace= True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_18828\584226.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# В Северной Америке самые популярные платформы: PS4, XOne, X360, PS3 и 3DS;
# <br/>В Европе: PS4, PS3, XOne, PC и 3DS;
# <br/>В Японии: 3DS, PS3, PSV, PS4 и WiiU.

# %% [markdown]
# <div class="alert alert-dange r">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Круговая диаграмма из ТОП-5 искажает доли рынка, которые занимают первые топ-5 платформ, т.к. их сумма продаж делится на 100%, но у нас имеются другие платформы, которые также занимают определенную долю рынка

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Круговая диаграмма из ТОП-5 искажает доли рынка, которые занимают первые топ-5 платформ, т.к. их сумма продаж делится на 100%, но у нас имеются другие платформы, которые также занимают определенную долю рынка

# %%
def popular_genre_multiple():
    regions = [('na_sales', 'Северной Америке'), ('eu_sales', 'Европе'), ('jp_sales', 'Японии')]
    fig, axes = plt.subplots(1, 3, figsize=(18, 6)) 
    fig.suptitle('Обзор популярных жанров') 
    for i, (region, name) in enumerate(regions):
       sales_t = actual_games.pivot_table(index='genre', values=region, aggfunc='sum')\
                                     .sort_values(ascending=False, by=region)
       platform_sales = sales_t[:5]
       platform_sales.loc[len(platform_sales.index)] = sales_t[5:].sum()
       platform_sales.rename(index={5:"other"}, inplace= True)
       platform_sales.plot(kind='pie', y=region, autopct='%1.1f%%', 
                           colors=['#7169c9', '#a3a0fb', '#cfc3ff', '#e8e5fd', '#f0f0f0'],
                           ax=axes[i], legend=False, title='Популярность жанров в ' + name)
       axes[i].set_ylabel('')
    plt.show()

# %%
popular_genre_multiple()
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_18828\2265539430.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   platform_sales.loc[len(platform_sales.index)] = sales_t[5:].sum()
# C:\Users\artem\AppData\Local\Temp\ipykernel_18828\2265539430.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   platform_sales.rename(index={5:"other"}, inplace= True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_18828\2265539430.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# В Северной Америке самые популярные жанры: action, shooter, sports, role-playing и misc;
# <br/>В Европе картина похожа, но с другим распределением: action, shooter, sports, role-playing и racing;
# <br/>В Японии: role-playing, action, misc, fighting и shooter.

# %%
def popular_rating_multiple():
    regions = [('na_sales', 'Северной Америке'), ('eu_sales', 'Европе'), ('jp_sales', 'Японии')]
    fig, axes = plt.subplots(1, 3, figsize=(18, 6)) 
    fig.suptitle('Обзор популярных рейтингов') 
    for i, (region, name) in enumerate(regions):
        platform_sales = actual_games.pivot_table(index='rating', values=region, aggfunc='sum')\
                                     .sort_values(ascending=False, by=region)[:5]
        platform_sales.plot(kind='pie', y=region, autopct='%1.1f%%', 
                            colors=['#7169c9', '#a3a0fb', '#cfc3ff', '#e8e5fd', '#f0f0f0'],
                            ax=axes[i], legend=False, title='Популярность рейтингов в ' + name)
        axes[i].set_ylabel('')
    plt.show()

# %%
popular_rating_multiple()

# %% [markdown]
# В Америке и Европе картина идентичная, на первом месте игры для взрослых с рейтингом М («Mature»).
# <br/>И тут рынок Японии же - игры с рейтингом М только на 3 месте, а лидируют игры с рейтингом Т («Teen») и Е («Everyone»).

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец
#
# Стоит оформить графики раздела TOП-5:
#
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделала, надеюсь все ок. Очень долго я соображала тут конечно, если честно :)
# <br /> Для "других" платформ написала код вначале 4 пункта, но я не понимаю где его воткнуть в функции...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Если решишь изменить свою функцию, то создание 6-ой строки мы включаем в цикл
#
#             for i, (region, name) in enumerate(regions):
#                 platform_sales = actual_games.pivot_table(index='rating', values=region, aggfunc='sum')\
#                                              .sort_values(ascending=False, by=region)[:5]
#                 platform_sales.plot(kind='pie', y=region, autopct='%1.1f%%',
#                                     colors=['#7169c9', '#a3a0fb', '#cfc3ff', '#e8e5fd', '#f0f0f0'],
#                                     ax=axes[i], legend=False, title='Популярность рейтингов в ' + name)
#                 axes[i].set_ylabel('')
#
# после
#
#                 platform_sales = actual_games.pivot_table(index='rating', values=region, aggfunc='sum')\
#                                      .sort_values(ascending=False, by=region)[:5]
#
# этой строкой мы создаем ТОП-5, после чего к этой таблице из пяти строчек стоит добавить — шестую строку  с суммой оставшихся продаж

# %% [markdown]
# ### check

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Предлагаю попробовать создать шестую категорию — «Другие» и объединить туда все не вошедшие в ТОП-5 строчки
#
# Добавил пример создания строки (у меня он развернут в обратном порядке)
#
#
# На данном этапе интересует сама выборка ТОП-5 плюс категория «Другие», без графиков
#
# Если будут сложности с вариантом расчета сразу для трех регионов, стоит выполнить второй пример

# %%
# check
# import pandas as pd
df_app = pd.DataFrame([['ps',1,2,3],
                   ['xone',3,5,6],
                   ['pc',8,9,10],
                   ['ps3',1,7,3],
                   ['ps4',5,2,3]], columns=['platform', 'eu','jp','na'])
display(df_app)

df_other = df_app[3:]
df_other = df_other.append({'platform': 'Other', 'eu': df_app['eu'].sum()-df_app['eu'][3:].sum(),
                  'jp': df_app['jp'].sum()-df_app['jp'][3:].sum(),
                  'na': df_app['na'].sum()-df_app['na'][3:].sum()}, ignore_index = True)
df_other
# Out:
#   platform  eu  jp  na
# 0       ps   1   2   3
# 1     xone   3   5   6
# 2       pc   8   9  10
# 3      ps3   1   7   3
# 4      ps4   5   2   3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18828\1606340797.py in ?()
# ---> 11 # check
#      12 # import pandas as pd
#      13 df_app = pd.DataFrame([['ps',1,2,3],
#      14                    ['xone',3,5,6],
#
# ~\PycharmProjects\pythonProject5\venv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Или берем одну выборку ⬇⬇⬇ и создаем из неё выборку с 6-ю строчками.
#
# Это базовый навык работы с таблицей, навык по трансформации — из 10-ти строчек получить 6 в которой первые пять это топовые позиции, а последняя шестая — это сумма всех остальных строк, кроме первых пяти
#
# ![image.png](attachment:image.png)
#
# Если ты не понимаешь, как выполнить это, тогда стоит задать вопрос преподавателю по проектам в чате «пачки». Также ты можешь написать вопрос или пример кода в проекте и опять отправить его на проверку — так я смогу тебе ответить
#
#
# Можно посмотреть на порядок применения loc
#
# https://tonais.ru/library/zamena-odnogo-ili-neskolkih-znacheniy-v-stolbtse-v-dataframe?ysclid=l5jjs9blfj495302948
#
# https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79 (ссылка может не работать)
#
# https://www.marsja.se/how-to-use-iloc-and-loc-for-indexing-and-slicing-pandas-dataframes/
#
#
# Выбор способа создания за тобой

# %%
# check

actual_games.groupby('platform').agg({'na_sales': 'sum'}).sort_values(by='na_sales', ascending=False)
# Out:
#           na_sales
# platform
# PS4          98.61
# XOne         81.27
# X360         28.30
# 3DS          22.64
# PS3          22.05
# WiiU         19.36
# PC            7.23
# PSV           2.52
# Wii           2.08
# PSP           0.00

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга

# %% [markdown]
# **Вывод:**
# - Американцы предпочитают PS4, XOne, X360, PS3 и 3DS. Их любимые жанры - action, shooter, sports, role-playing и misc. Рейтинги игр М и Е, М со значительным отрывом.
# - Европейцам больше всего нравится платформа PS4 (на первом месте с большим отрывом), после PS3, XOne, PC и 3DS. Предпочитают следующие жанры: action, shooter, sports, role-playing и racing. Рейтинги игр М и Е, М со значительным отрывом.
# - ТОП-5 японцев - это 3DS (с огромным отрывом), далее PS3, PSV, PS4 и WiiU. Люимые жанры - role-playing, action, misc, fighting и shooter. Рейтинги игр Т, Е и М, где Е и М практически равны.

# %% [markdown]
# ### Проверьте гипотезы

# %% [markdown]
# Исходя из всех полученных данных проверим несколько гипотез.
#
# <br/>Т.к. имеем две независимые выборки, воспользуемся t-критерием Стьюдента и проверим равенства средних значений в двух выборках.
# <br/>Пороговое значение alpha определим как 0.5 (из двух общепринятых 0.1 и 0.5).

# %% [markdown]
# #### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые:

# %% [markdown]
# - Н0 (нулевая гипотеза) - средние пользовательские рейтинги платформ Xbox One и PC **одинаковые**;
# - Н1 (альтернативная гипотеза) - средние пользовательские рейтинги платформ Xbox One и PC **отличаются между собой**.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно, для акцентирования можно использовать в нулевой гипотезе слово равны

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %%
alpha = 0.5

results = st.ttest_ind(
    actual_games[actual_games['platform'] == 'PC']['user_score'].dropna(),
    actual_games[actual_games['platform'] == 'XOne']['user_score'].dropna()
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.10450507919348415
# Отвергаем нулевую гипотезу

# %% [markdown]
# Отвергаем нулевую гипотезу о том, что средние рейтинги одинаковы. Вероятно, что средние рейтинги платформ будут отличаться.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.14012658403611647

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправила вывод.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Если выбрать уровень значимости в 50%, то у нас большая часть стат тестов не пройдет, а в медицине наверно и все 90%. Т.е. мы не сможем открыть и запустить в производство новые лекарства
#
# стоит корректно выбрать уровень значимости и поправить вывод
#
# [Объяснение P-значений и статистической значимости](https://www.codecamp.ru/blog/p-values-statistical-significance/?ysclid=lm88qnc76l397155692)
#
# стоит исправить этот комментарий и во втором стат тесте

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.19124505225722097
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# #### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные:

# %% [markdown]
# - Н0 (нулевая гипотеза) - средние пользовательские рейтинги жанров Action и Sports **одинаковые**.
# - Н1 (альтернативная гипотеза) - средние пользовательские рейтинги жанров Action и Sports **отличаются между собой**.

# %%
alpha =  0.5

results = st.ttest_ind(
    actual_games[actual_games['genre'] == 'Action']['user_score'].dropna(),
    actual_games[actual_games['genre'] == 'Sports']['user_score'].dropna()
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')

# %% [markdown]
# Отвергаем нулевую гипотезу о том, что средние рейтинги одинаковые. Вероятно, что средние рейтинги жанров будут отличаться.

# %% [markdown]
# **Вывод:**
# - Вероятно, что средние рейтинги платформ Xbox One и PC будут идентичны.
# - Вероятно, что средние рейтинги жанров Action и Sports будут отличаться.

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# **Основной целью исследования** было выявить определяющие успешность игры закономерности. Эта информация была необходима для планирования продаж на 2017 год.
#
# Для исследования были предоставлены данные со следующими **описанием**:
#
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# **Подготовка данных:**
#
# В результате подготовки данных, названия столбцов были приведены к нижнему регистру, пропуски и дубликаты - обработаны, тип данных столбцов year_of_release и user_score - скорректирован, столбец sum_sales с данными о суммарных продажах во всех регионах - добавлен.
#
# **Исследовательский анализ данных:**
#
# Выпуск игр начался с 1980 год, но набирать популярность этот вид досуга стал только к середине 90-х годов. Скорее всего это связано с тем, что персональные компьютеры стали доступны широкому кругу пользователей.
# <br/>После 2000-х наблюдается резкий рост, это также связано со стремительным развинием технологической отрасли.
# <br/>Пик выпуска игр приходится на 2008-2009 годы, спад после 2010 года можно объяснить разгаром мирового экономического кризиса (2008-2013).
# <br/>После окончания острой фазы кризиса вновь появились ресурсы на разработку, т.к. на нее обычно уходит несколько лет, очередной рост виден к 2015 году.
#
# Лидеры общемировых продаж - все версии PS, консоли Nintendo - DS и Wii, и X360 от Microsoft.
#
# Средний срок жизни платформы - 10 лет.
#
# Актуальный период для дальнейшего исследования - с 2014 по 2016 год.
#
# Потенциально прибыльными можно назвать следующие платформы: PS4, XOne, 3DS, PS3, X360, WiiU, PC и PSV.
# Лидер продаж - PS4 - 288.15 млн. проданных копий.
# <br/>В два раза меньше продаж у модели - XOne - 140.36 млн. проданных копий.
# <br/>Далее - 3DS - 86.68 млн. проданных копий, PS3 - 68.18 млн. проданных копий, X360 - 48.22 млн. проданных копий, WiiU - 42.98 млн. проданных копий, PC - 27.05 млн. проданных копий и PSV - 22.40 млн. проданных копий.
# <br/>PS4 на текущий момент является наиболее перспективной, до выхода новой версии. Несмотря на второе место, на PS3 не стоит делать ставку, т.к. ее релиз состоялся в 2006 году, то, помня о средней продолжительности жизненого цикла платформы в, примерно, 10 лет, можно предположить, что спрос будет падать.
# <br/>Релиз X360 состоялся в 2005 году, ситуация аналогичная с PS3, спрос так же будет падать.
# XOne, выпущенная в 2013 году, тоже может быть потенциально прибыльной.
#
# Наиболее потенциально коммерчески успешные платформы: PS4, XOne, WiiU, X360 и Wii. У остальных медиана значительно ниже.
#
# Оценки критиков имеют определенное значение повышают шансы на продажу по всем рассмотренным платформам, в отличие от оценок пользователей. Но на платформе 3DS оценки пользователей влияют на продажи значительно больше.
#
# Наиболее популярные жанры - action, role-playing  и adventure.
# <br/>Игры в жанрах action, sports и adventure, приносят наибольшее количество продаж.
#
# **Портрет пользователя каждого региона:**
#
# Американцы предпочитают PS4, XOne, X360, PS3 и 3DS. Их любимые жанры - action, shooter, sports, role-playing и misc. Рейтинги игр М и Е, М со значительным отрывом.
# <br/>Европейцам больше всего нравится платформа PS4 (на первом месте с большим отрывом), после PS3, XOne, PC и 3DS. Предпочитают следующие жанры: action, shooter, sports, role-playing и racing. Рейтинги игр М и Е, М со значительным отрывом.
# <br/>ТОП-5 японцев - это 3DS (с огромным отрывом), далее PS3, PSV, PS4 и WiiU. Люимые жанры - role-playing, action, misc, fighting и shooter. Рейтинги игр Т, Е и М, где Е и М практически равны.
#
# **Проверка гипотез:**
#
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые: по результатам теста отвергаем нулевую гипотезу о том, что средние рейтинги одинаковы. Вероятно, что **средние рейтинги платформ будут отличаться**.
#
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные: по результатам теста отвергаем нулевую гипотезу о том, что средние рейтинги одинаковы. Вероятно, что **средние рейтинги жанров будут отличаться**.

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после исправления всех комментариев, можно обновить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправила вывод.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнены практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + обработать пропуски и сократить категории в рейтингах ESRB — на твое усмотрение
#  + поправить перечень перспективных платформ
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера </b></font>
# <br />
# <font size="3", color = "black">
# <br />Восстановил комментарий
#
#
# Может пригодиться
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
# Плюс
#
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Клавишей z можно восстановить удаленные строки, только аккуратно — каждое нажатие восстанавливает одну строку, причем это может быть в самых разных частях проекта, например удалил строку в начале проекта, а затем переместился в эту часть проекта и нажал на кнопку z, строка восстановится в начале проекта, а ты даже не заметишь этого
